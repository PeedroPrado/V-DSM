# %% [markdown]
# <a href="https://colab.research.google.com/github/PeedroPrado/V-DSM/blob/main/Exercicio_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

iris = fetch_ucirepo(id=53)

print(iris)
# Out:
# {'data': {'ids': None, 'features':      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns], 'targets':               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# ...

# %%
X = iris.data.features
y = iris.data.targets

# %%
largura_sepala = X["sepal width"]
print(largura_sepala)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width, Length: 150, dtype: float64

# %%
media = np.mean(largura_sepala)
print(media)

print(f"Média:  {media:.2f}cm")
# Out:
# 3.0540000000000003
# Média:  3.05cm

# %%
mediana = np.median(largura_sepala)
print(mediana)

print(f"Mediana:  {mediana:.2f}cm")
# Out:
# 3.0
# Mediana:  3.00cm

# %%
X = iris.data.features
y = iris.data.targets

print("Formato de X: ", X.shape)
print("Formato de y: ", y.shape)

largura_sepala = X["sepal width"]

print(f"Média: {media:.2f} cm")
print(f"Mediana: {mediana:.2f} cm")
# Out:
# Formato de X:  (150, 4)
# Formato de y:  (150, 1)
# Média: 3.05 cm
# Mediana: 3.00 cm

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(largura_sepala)

plt.title("Boxplot da Largura da Sépala")
plt.xlabel("Largura da Sépala")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(largura_sepala, bins=10)

plt.title("Histograma da Largura da Sépala")
plt.xlabel("Largura da Sépala")
plt.ylabel("Frequência")

plt.show()
